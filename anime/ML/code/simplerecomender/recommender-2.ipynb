# %%
genre = input("Please select a genre")
studio = input("Please select a studio")

# %%
import pandas as pd
data = pd.read_csv('S:\Projects/anime\data/dup_data.csv')
dup_data = data.copy()

animes = dup_data[(dup_data['Genre'] == genre) | (dup_data['Studio'] == studio)]

# %%
c = animes['Scores'].mean()

# %%
def weight_rating(x,c=c):
    f = x['Favorites']
    f = int(f)
    m = x['Members']
    m = int(m)
    s = x['Scores']
    s = int(s)
    r = (f/m)*(s/c)
    return r

# %%
animes['rec_score'] = animes.apply(weight_rating,axis=1)
sort_data = animes.sort_values('rec_score',ascending=False)
sort_data
# Out:
# C:\Users\mvspr\AppData\Local\Temp\ipykernel_20228\663166974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   animes['rec_score'] = animes.apply(weight_rating,axis=1)
#     Episodes            Status                         Ratings  Scores  Rank  \
# 61   Unknown  Currently Airing       PG-13 - Teens 13 or older    8.65    63
# 23       148   Finished Airing       PG-13 - Teens 13 or older    9.05     7
# 24       148   Finished Airing       PG-13 - Teens 13 or older    9.05     7
# 4         64   Finished Airing  R - 17+ (violence & profanity)    9.14     2
# 121       26   Finished Airing       PG-13 - Teens 13 or older    8.34   203
# ..       ...               ...                             ...     ...   ...
# ...
